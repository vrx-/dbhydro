# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set()

# %%
path = 'datasets/REPORT-8.csv'
df = pd.read_csv(path, parse_dates=['Collection_Date'])
nvars = df['Test Name'].unique()
nvars
# Out:
# array(['PHOSPHATE, ORTHO AS P', 'PHOSPHATE, TOTAL AS P',
#        'PHOSPHATE, DISSOLVED AS P'], dtype=object)

# %%
df.head()
# Out:
#   Project Code Station ID Sample ID  First Trigger Date     Collection_Date  \
# 0            Y       L001      0044                 NaN 1972-12-11 00:00:00
# 1            Y       L001      0045                 NaN 1972-12-11 00:00:00
# 2            Y       L001      0044                 NaN 1972-12-11 00:00:00
# 3            Y       L001      0045                 NaN 1972-12-11 00:00:00
# 4            Y       L001      0076                 NaN 1973-02-05 16:05:00
#
#   Sample Type New Collection Method  Depth Depth Unit Matrix  ...  \
# 0            SAMP                 G    0.0        NaN     SW  ...
# 1            SAMP                 G    2.0        NaN     SW  ...
# 2            SAMP                 G    0.0        NaN     SW  ...
# 3            SAMP                 G    2.0        NaN     SW  ...
# 4            SAMP                 G    0.0        NaN     SW  ...
#
#    Filtration Date Sample Type  QC Type Discharge Up/Down Stream  \
# ...

# %%
df.dtypes
# Out:
# Project Code                  object
# Station ID                    object
# Sample ID                     object
# First Trigger Date           float64
# Collection_Date       datetime64[ns]
# Sample Type New               object
# Collection Method             object
# Depth                        float64
# Depth Unit                    object
# Matrix                        object
# Test Number                    int64
# Test Name                     object
# Storet Code                  float64
# Method                        object
# Measure Date                  object
# Value                        float64
# Sigfig Value                 float64
# Uncertainty                   object
# MDL                          float64
# PQL                          float64
# RDL                          float64
# Units                         object
# Remark Code                   object
# Flag                         float64
# Receive Date                  object
# ...

# %%
fig, axes = plt.subplots(2,1, figsize=(12,7), sharex=True)
ylims = ([.15, .4]) # upper limits for y axis
for var, ax, lim in zip(nvars[:-1], axes, ylims):
    sub = df.where(df['Test Name']==var)
    sub.plot(x='Collection_Date', y='Value', ax=ax, legend=False)
    ax.set_ylabel(var+' [mg/L]')
    ax.set_ylim(0, lim)
    
    ax2 = ax.twinx()
    var2 = sub['Value']/.031
    ax2.plot(sub['Collection_Date'], var2)
    ax2.set_ylabel(var+r' [$\mu$M]')
    ax2.grid(None)
    ax2.set_ylim(0, lim/.031)

# fig.suptitle('L001', )
# df.where(df['Test Name']==var).plot(x='Collection_Date', y='Value', ax=axes[0])
# df.where(df['Test Name']==var).plot(x='Collection_Date', y='Value', ax=axes[0])

# %%
path = 'datasets/REPORT-9.csv'
df2 = pd.read_csv(path, parse_dates=['Collection_Date'])
nvars2 = df2['Test Name'].unique()
nvars2
# Out:
# array(['NITRATE-N', 'TOTAL NITROGEN'], dtype=object)

# %%
fig, axes = plt.subplots(2,1, figsize=(12,7), sharex=True)
ylims = ([.7, 3])
for var, ax, lim in zip(nvars2, axes, ylims):
    sub = df2.where(df2['Test Name']==var)
    sub.plot(x='Collection_Date', y='Value', ax=ax, legend=False)
    ax.set_ylabel(var+' [mg/L]')
    ax.set_ylim(0, lim)
    
    ax2 = ax.twinx()
    var2 = sub['Value']/.014
    ax2.plot(sub['Collection_Date'], var2)
    ax2.set_ylabel(var+r' [$\mu$M]')
    ax2.grid(None)
    ax2.set_ylim(0, lim/.014)
